# %%
#I will use Matplotlib in this notebook to make the line plot.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Cust_Segmentation.csv")
df
# Out:
#      Customer Id  Age  Edu  Years Employed  Income  Card Debt  Other Debt  \
# 0              1   41    2               6      19      0.124       1.073
# 1              2   47    1              26     100      4.582       8.218
# 2              3   33    2              10      57      6.111       5.802
# 3              4   29    2               4      19      0.681       0.516
# 4              5   47    1              31     253      9.308       8.908
# ..           ...  ...  ...             ...     ...        ...         ...
# 845          846   27    1               5      26      0.548       1.220
# 846          847   28    2               7      34      0.359       2.021
# 847          848   25    4               0      18      2.802       3.210
# 848          849   32    1              12      28      0.116       0.696
# 849          850   52    1              16      64      1.866       3.638
#
#      Defaulted Address  DebtIncomeRatio
# ...

# %%
id = df["Customer Id"]
income = df["Income"]

# %%
plt.plot(id, income)
plt.xlabel('Customer ID number')
plt.ylabel('Income')
plt.title('Customer ID num vs Income')
plt.grid(True)
plt.show()

# %%
#Observing the line plot above, it seems like there is no relationship between the income and the customer id.

# %%
#Separate two plots
df = pd.DataFrame({

   'position': [1, 8, 27, 54, 125],

   'velocity': [1, 4, 9, 16, 25]

   }, index=[1, 2, 3, 4, 5])

lines = df.plot.line()

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)
