# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("FuelConsumption.csv")
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
df.plot(x = "CO2EMISSIONS", y = "CYLINDERS", kind = "scatter", title = "fuel consumption in city vs # cylinders")
# Out:
# <Axes: title={'center': 'fuel consumption in city vs # cylinders'}, xlabel='CO2EMISSIONS', ylabel='CYLINDERS'>

# %%
# It seems like there is a correation between the fuel consumption in city and the number of cylinders a car has
df[["FUELCONSUMPTION_CITY", "CYLINDERS"]].corr()
# Out:
#                       FUELCONSUMPTION_CITY  CYLINDERS
# FUELCONSUMPTION_CITY              1.000000   0.796473
# CYLINDERS                         0.796473   1.000000

# %%
# It seems like there is a correation between the fuel consumption on the highway and the number of cylinders a car has
# However it is less obvious than the previous correlation
df[["FUELCONSUMPTION_HWY", "CYLINDERS"]].corr()
# Out:
#                      FUELCONSUMPTION_HWY  CYLINDERS
# FUELCONSUMPTION_HWY             1.000000   0.724594
# CYLINDERS                       0.724594   1.000000

# %%
sns.boxplot(x = "TRANSMISSION", y = "FUELCONSUMPTION_CITY", data=df)
plt.title("Relation between transmission and fuel consumption")
# Out:
# Text(0.5, 1.0, 'Relation between transmission and fuel consumption')

# %%
df["FUELCONSUMPTION_CITY"].describe()
# Out:
# count    1067.000000
# mean       13.296532
# std         4.101253
# min         4.600000
# 25%        10.250000
# 50%        12.600000
# 75%        15.550000
# max        30.200000
# Name: FUELCONSUMPTION_CITY, dtype: float64

# %%
df["TRANSMISSION"].value_counts()
# Out:
# TRANSMISSION
# A6     222
# AS6    189
# M6     141
# A8      87
# AS8     80
# AS7     76
# M5      48
# AV      46
# A4      45
# AM7     34
# A5      30
# A7      12
# AV6     11
# AS5     10
# M7       9
# A9       8
# AM6      6
# AV7      5
# AV8      3
# AS9      2
# AM5      2
# AS4      1
# Name: count, dtype: int64

# %%
#sort values by co2 emission in descanding order
df.sort_values(by='CO2EMISSIONS', ascending=False)
# Out:
#       MODELYEAR        MAKE                   MODEL     VEHICLECLASS  \
# 349        2014        FORD              E350 WAGON  VAN - PASSENGER
# 75         2014     BENTLEY                MULSANNE         MID-SIZE
# 227        2014   CHEVROLET  EXPRESS 3500 PASSENGER  VAN - PASSENGER
# 451        2014         GMC   SAVANA 3500 PASSENGER  VAN - PASSENGER
# 224        2014   CHEVROLET  EXPRESS 2500 PASSENGER  VAN - PASSENGER
# ...         ...         ...                     ...              ...
# 415        2014        FORD           FUSION HYBRID         MID-SIZE
# 1042       2014  VOLKSWAGEN      JETTA TURBO HYBRID          COMPACT
# 987        2014      TOYOTA                   PRIUS         MID-SIZE
# 487        2014       HONDA           ACCORD HYBRID         MID-SIZE
# 988        2014      TOYOTA                 PRIUS c          COMPACT
#
#       ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# ...
